# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
req= requests.get('https://smashlahore.com/')

# %%
soup= BeautifulSoup(req.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This is Squarespace. --><!-- gar-mauve-7dc7 -->
# <base href=""/>
# <meta charset="utf-8">
# <title>SMASH Lahore</title>
# <link href="https://images.squarespace-cdn.com/content/v1/607db38b1f738b76082b1e6d/e64dc690-9148-4448-9454-b101bb6ae547/favicon.ico?format=100w" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://smashlahore.com" rel="canonical"/>
# <meta content="SMASH Lahore" property="og:site_name">
# <meta content="SMASH Lahore" property="og:title"/>
# <meta content="https://smashlahore.com" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
t=soup.title

# %%
print(t.prettify())
# Out:
# <title>
#  SMASH Lahore
# </title>

# %%
print(t.get_text())
# Out:
# SMASH Lahore
